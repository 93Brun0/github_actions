# %% [markdown]
# <a href="https://colab.research.google.com/github/93Brun0/github_actions/blob/main/S%26P500BIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# === Step 1: Setup ===
import pandas as pd
import requests
import time

# Mount Google Drive (optional, if you want to save to your Drive)
# from google.colab import drive
# drive.mount('/content/drive')

# === Step 2: Load ticker list (local fallback ready) ===
try:
    sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_df = pd.read_html(sp500_url)[0]
    print("✅ Wikipedia fetch successful.")
except:
    from google.colab import files
    uploaded = files.upload()  # Upload sp500_tickers.csv from your computer
    sp500_df = pd.read_csv('sp500_tickers.csv')
    print("⚠️ Wikipedia failed — using uploaded CSV.")

tickers = sp500_df['Symbol'].str.replace('.', '-', regex=False).tolist()

# === Step 3: Set API key ===
API_KEY = 'wfde30s3RwhH2KgloTh5F4xc5Fo3TITG'  # Replace with your valid FMP key

# === Step 4: Collection loop ===
all_data = []
skipped = []

for i, ticker in enumerate(tickers):
    print(f"[{i+1}/{len(tickers)}] {ticker}")

    try:
        income = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/{ticker}?limit=5&apikey={API_KEY}').json()
        profile = requests.get(f'https://financialmodelingprep.com/api/v3/profile/{ticker}?apikey={API_KEY}').json()
        balance = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{ticker}?limit=5&apikey={API_KEY}').json()

        if not income or not profile or not balance:
            skipped.append((ticker, 'missing data'))
            continue

        for year in income:
            y = year['calendarYear']
            bmatch = next((b for b in balance if b['calendarYear'] == y), None)
            if not bmatch: continue

            ni = year.get('netIncome')
            ta = bmatch.get('totalAssets')
            te = bmatch.get('totalStockholdersEquity')

            all_data.append({
                'Ticker': ticker,
                'Year': y,
                'Net Income': ni,
                'Total Assets': ta,
                'Total Equity': te,
                'ROA': ni/ta if ta else None,
                'ROE': ni/te if te else None,
                'Company': profile[0].get('companyName'),
                'Revenue': year.get('revenue'),
                'EPS': year.get('eps'),
                'Sector': profile[0].get('sector'),
                'Industry': profile[0].get('industry'),
            })

    except Exception as e:
        skipped.append((ticker, str(e)))
        continue

    if (i+1) % 50 == 0:
        df_checkpoint = pd.DataFrame(all_data)
        df_checkpoint.to_csv('checkpoint.csv', index=False)
        print("✅ Saved checkpoint.")

    time.sleep(1.2)

# === Step 5: Save everything ===
df_final = pd.DataFrame(all_data)
df_final.to_csv('sp500_fundamentals_colab.csv', index=False)
pd.DataFrame(skipped, columns=['Ticker', 'Reason']).to_csv('skipped_tickers_colab.csv', index=False)

print("✅ All done.")
# Out:
# ✅ Wikipedia fetch successful.
# [1/503] MMM
# [2/503] AOS
# [3/503] ABT
# [4/503] ABBV
# [5/503] ACN
# [6/503] ADBE
# [7/503] AMD
# [8/503] AES
# [9/503] AFL
# [10/503] A
# [11/503] APD
# [12/503] ABNB
# [13/503] AKAM
# [14/503] ALB
# [15/503] ARE
# [16/503] ALGN
# [17/503] ALLE
# [18/503] LNT
# [19/503] ALL
# [20/503] GOOGL
# [21/503] GOOG
# [22/503] MO
# [23/503] AMZN
# [24/503] AMCR
# [25/503] AEE
# [26/503] AEP
# [27/503] AXP
# [28/503] AIG
# [29/503] AMT
# [30/503] AWK
files.download('skipped_tickers_colab.csv')

# %%
# === Step 1: Setup ===
import pandas as pd
import requests
import time

# === Step 2: Load ticker list ===
try:
    sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_df = pd.read_html(sp500_url)[0]
    print("✅ Wikipedia fetch successful.")
except:
    from google.colab import files
    uploaded = files.upload()  # Upload sp500_tickers.csv manually if needed
    sp500_df = pd.read_csv('sp500_tickers.csv')
    print("⚠️ Wikipedia failed — using uploaded CSV.")

tickers = sp500_df['Symbol'].str.replace('.', '-', regex=False).tolist()

# === Step 3: Set your FMP API key ===
API_KEY = '4xEiP6KUhNgHm9kqAsQeAZoSCzvUIBo4'  # Replace with your actual key

# === Step 4: Main data collection loop ===
all_data = []
skipped = []

for i, ticker in enumerate(tickers):
    print(f"[{i+1}/{len(tickers)}] Processing {ticker}")

    try:
        # Get income statement
        income = requests.get(
            f'https://financialmodelingprep.com/api/v3/income-statement/{ticker}?limit=5&apikey={API_KEY}'
        ).json()
        if not isinstance(income, list) or len(income) == 0:
            skipped.append((ticker, 'income - invalid or empty'))
            continue

        # Get profile
        profile = requests.get(
            f'https://financialmodelingprep.com/api/v3/profile/{ticker}?apikey={API_KEY}'
        ).json()
        if not isinstance(profile, list) or len(profile) == 0:
            skipped.append((ticker, 'profile - invalid or empty'))
            continue
        profile = profile[0]

        # Get balance sheet
        balance = requests.get(
            f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/{ticker}?limit=5&apikey={API_KEY}'
        ).json()
        if not isinstance(balance, list) or len(balance) == 0:
            skipped.append((ticker, 'balance - invalid or empty'))
            continue

        # Match by year
        for year in income:
            y = year.get('calendarYear')
            bmatch = next((b for b in balance if b.get('calendarYear') == y), None)
            if not bmatch:
                continue

            ni = year.get('netIncome')
            ta = bmatch.get('totalAssets')
            te = bmatch.get('totalStockholdersEquity')

            all_data.append({
                'Ticker': ticker,
                'Year': y,
                'Net Income': ni,
                'Total Assets': ta,
                'Total Equity': te,
                'ROA': ni/ta if ta else None,
                'ROE': ni/te if te else None,
                'Company': profile.get('companyName'),
                'Revenue': year.get('revenue'),
                'EPS': year.get('eps'),
                'Sector': profile.get('sector'),
                'Industry': profile.get('industry'),
            })

    except Exception as e:
        skipped.append((ticker, f'exception: {str(e)}'))
        continue

    if (i + 1) % 50 == 0:
        pd.DataFrame(all_data).to_csv('checkpoint.csv', index=False)
        print("💾 Saved checkpoint")

    time.sleep(1.2)

# === Step 5: Save results ===
pd.DataFrame(all_data).to_csv('sp500_fundamentals_colab.csv', index=False)
pd.DataFrame(skipped, columns=['Ticker', 'Reason']).to_csv('skipped_tickers_colab.csv', index=False)

print("✅ All done.")
# Out:
# ✅ Wikipedia fetch successful.
# [1/503] Processing MMM
# [2/503] Processing AOS
# [3/503] Processing ABT
# [4/503] Processing ABBV
# [5/503] Processing ACN
# [6/503] Processing ADBE
# [7/503] Processing AMD
# [8/503] Processing AES
# [9/503] Processing AFL
# [10/503] Processing A
# [11/503] Processing APD
# [12/503] Processing ABNB
# [13/503] Processing AKAM
# [14/503] Processing ALB
# [15/503] Processing ARE
# [16/503] Processing ALGN
# [17/503] Processing ALLE
# [18/503] Processing LNT
# [19/503] Processing ALL
# [20/503] Processing GOOGL
# [21/503] Processing GOOG
# [22/503] Processing MO
# [23/503] Processing AMZN
# [24/503] Processing AMCR
# [25/503] Processing AEE
# [26/503] Processing AEP
# [27/503] Processing AXP
# [28/503] Processing AIG
# [29/503] Processing AMT
# [30/503] Processing AWK
# [31/503] Processing AMP
# [32/503] Processing AME
# [33/503] Processing AMGN
# [34/503] Processing APH
# [35/503] Processing ADI
# [36/503] Processing ANSS
# [37/503] Processing AON
# [38/503] Processing APA
# [39/503] Processing APO
# [40/503] Processing AAPL
# [41/503] Processing AMAT
# [42/503] Processing APTV
# [43/503] Processing ACGL
# [44/503] Processing ADM
# [45/503] Processing ANET
# [46/503] Processing AJG
# [47/503] Processing AIZ
# [48/503] Processing T
# [49/503] Processing ATO
# [50/503] Processing ADSK
# 💾 Saved checkpoint
# [51/503] Processing ADP
# [52/503] Processing AZO
# [53/503] Processing AVB
# [54/503] Processing AVY
# [55/503] Processing AXON
# [56/503] Processing BKR
# [57/503] Processing BALL
# [58/503] Processing BAC
# [59/503] Processing BAX
# [60/503] Processing BDX
# [61/503] Processing BRK-B
# [62/503] Processing BBY
# [63/503] Processing TECH
# [64/503] Processing BIIB
# [65/503] Processing BLK
# [66/503] Processing BX
# [67/503] Processing BK
# [68/503] Processing BA
# [69/503] Processing BKNG
# [70/503] Processing BSX
# [71/503] Processing BMY
# [72/503] Processing AVGO
# [73/503] Processing BR
# [74/503] Processing BRO
# [75/503] Processing BF-B
# [76/503] Processing BLDR
# [77/503] Processing BG
# [78/503] Processing BXP
# [79/503] Processing CHRW
# [80/503] Processing CDNS
# [81/503] Processing CZR
# [82/503] Processing CPT
# [83/503] Processing CPB
# [84/503] Processing COF
# [85/503] Processing CAH
# [86/503] Processing KMX
# [87/503] Processing CCL
# [88/503] Processing CARR
# [89/503] Processing CAT
# [90/503] Processing CBOE
# [91/503] Processing CBRE
# [92/503] Processing CDW
# [93/503] Processing COR
# [94/503] Processing CNC
# [95/503] Processing CNP
# [96/503] Processing CF
# [97/503] Processing CRL
# [98/503] Processing SCHW
# [99/503] Processing CHTR
# [100/503] Processing CVX
# [101/503] Processing CMG
# [102/503] Processing CB
# [103/503] Processing CHD
# [104/503] Processing CI
# [105/503] Processing CINF
# [106/503] Processing CTAS
# [107/503] Processing CSCO
# [108/503] Processing C
# [109/503] Processing CFG
# [110/503] Processing CLX
# [111/503] Processing CME
# [112/503] Processing CMS
# [113/503] Processing KO
# [114/503] Processing CTSH
# [115/503] Processing COIN
# [116/503] Processing CL
# [117/503] Processing CMCSA
# [118/503] Processing CAG
# [119/503] Processing COP
# [120/503] Processing ED
# [121/503] Processing STZ
# [122/503] Processing CEG
# [123/503] Processing COO
# [124/503] Processing CPRT
# [125/503] Processing GLW
# [126/503] Processing CPAY
# [127/503] Processing CTVA
# [128/503] Processing CSGP
# [129/503] Processing COST
# [130/503] Processing CTRA
# [131/503] Processing CRWD
# [132/503] Processing CCI
# [133/503] Processing CSX
# [134/503] Processing CMI
# [135/503] Processing CVS
# [136/503] Processing DHR
# [137/503] Processing DRI
# [138/503] Processing DVA
# [139/503] Processing DAY
# [140/503] Processing DECK
# [141/503] Processing DE
# [142/503] Processing DELL
# [143/503] Processing DAL
# [144/503] Processing DVN
# [145/503] Processing DXCM
# [146/503] Processing FANG
# [147/503] Processing DLR
# [148/503] Processing DG
# [149/503] Processing DLTR
# [150/503] Processing D
# [151/503] Processing DPZ
# [152/503] Processing DASH
# [153/503] Processing DOV
# [154/503] Processing DOW
# [155/503] Processing DHI
# [156/503] Processing DTE
# [157/503] Processing DUK
# [158/503] Processing DD
# [159/503] Processing EMN
# [160/503] Processing ETN
# [161/503] Processing EBAY
# [162/503] Processing ECL
# [163/503] Processing EIX
# [164/503] Processing EW
# [165/503] Processing EA
# [166/503] Processing ELV
# [167/503] Processing EMR
# [168/503] Processing ENPH
# [169/503] Processing ETR
# [170/503] Processing EOG
# [171/503] Processing EPAM
# [172/503] Processing EQT
# [173/503] Processing EFX
# [174/503] Processing EQIX
# [175/503] Processing EQR
# [176/503] Processing ERIE
# [177/503] Processing ESS
# [178/503] Processing EL
# [179/503] Processing EG
# [180/503] Processing EVRG
# [181/503] Processing ES
# [182/503] Processing EXC
# [183/503] Processing EXE
# [184/503] Processing EXPE
# [185/503] Processing EXPD
# [186/503] Processing EXR
# [187/503] Processing XOM
# [188/503] Processing FFIV
# [189/503] Processing FDS
# [190/503] Processing FICO
# [191/503] Processing FAST
# [192/503] Processing FRT
# [193/503] Processing FDX
# [194/503] Processing FIS
# [195/503] Processing FITB
# [196/503] Processing FSLR
# [197/503] Processing FE
# [198/503] Processing FI
# [199/503] Processing F
# [200/503] Processing FTNT
# [201/503] Processing FTV
# [202/503] Processing FOXA
# [203/503] Processing FOX
# [204/503] Processing BEN
# [205/503] Processing FCX
# [206/503] Processing GRMN
# [207/503] Processing IT
# [208/503] Processing GE
# [209/503] Processing GEHC
# [210/503] Processing GEV
# [211/503] Processing GEN
# [212/503] Processing GNRC
# [213/503] Processing GD
# [214/503] Processing GIS
# [215/503] Processing GM
# [216/503] Processing GPC
# [217/503] Processing GILD
# [218/503] Processing GPN
# [219/503] Processing GL
# [220/503] Processing GDDY
# [221/503] Processing GS
# [222/503] Processing HAL
# [223/503] Processing HIG
# [224/503] Processing HAS
# [225/503] Processing HCA
# [226/503] Processing DOC
# [227/503] Processing HSIC
# [228/503] Processing HSY
# [229/503] Processing HES
# [230/503] Processing HPE
# [231/503] Processing HLT
# [232/503] Processing HOLX
# [233/503] Processing HD
# [234/503] Processing HON
# [235/503] Processing HRL
# [236/503] Processing HST
# [237/503] Processing HWM
# [238/503] Processing HPQ
# [239/503] Processing HUBB
# [240/503] Processing HUM
# [241/503] Processing HBAN
# [242/503] Processing HII
# [243/503] Processing IBM
# [244/503] Processing IEX
# [245/503] Processing IDXX
# [246/503] Processing ITW
# [247/503] Processing INCY
# [248/503] Processing IR
# [249/503] Processing PODD
# [250/503] Processing INTC
# [251/503] Processing ICE
# [252/503] Processing IFF
# [253/503] Processing IP
# [254/503] Processing IPG
# [255/503] Processing INTU
# [256/503] Processing ISRG
# [257/503] Processing IVZ
# [258/503] Processing INVH
# [259/503] Processing IQV
# [260/503] Processing IRM
# [261/503] Processing JBHT
# [262/503] Processing JBL
# [263/503] Processing JKHY
# [264/503] Processing J
# [265/503] Processing JNJ
# [266/503] Processing JCI
# [267/503] Processing JPM
# [268/503] Processing JNPR
# [269/503] Processing K
# [270/503] Processing KVUE
# [271/503] Processing KDP
# [272/503] Processing KEY
# [273/503] Processing KEYS
# [274/503] Processing KMB
# [275/503] Processing KIM
# [276/503] Processing KMI
# [277/503] Processing KKR
# [278/503] Processing KLAC
# [279/503] Processing KHC
# [280/503] Processing KR
# [281/503] Processing LHX
# [282/503] Processing LH
# [283/503] Processing LRCX
# [284/503] Processing LW
# [285/503] Processing LVS
# [286/503] Processing LDOS
# [287/503] Processing LEN
# [288/503] Processing LII
# [289/503] Processing LLY
# [290/503] Processing LIN
# [291/503] Processing LYV
# [292/503] Processing LKQ
# [293/503] Processing LMT
# [294/503] Processing L
# [295/503] Processing LOW
# [296/503] Processing LULU
# [297/503] Processing LYB
# [298/503] Processing MTB
# [299/503] Processing MPC
# [300/503] Processing MKTX
# [301/503] Processing MAR
# [302/503] Processing MMC
# [303/503] Processing MLM
# [304/503] Processing MAS
# [305/503] Processing MA
# [306/503] Processing MTCH
# [307/503] Processing MKC
# [308/503] Processing MCD
# [309/503] Processing MCK
# [310/503] Processing MDT
# [311/503] Processing MRK
# [312/503] Processing META
# [313/503] Processing MET
# [314/503] Processing MTD
# [315/503] Processing MGM
# [316/503] Processing MCHP
# [317/503] Processing MU
# [318/503] Processing MSFT
# [319/503] Processing MAA
# [320/503] Processing MRNA
# [321/503] Processing MHK
# [322/503] Processing MOH
# [323/503] Processing TAP
# [324/503] Processing MDLZ
# [325/503] Processing MPWR
# [326/503] Processing MNST
# [327/503] Processing MCO
# [328/503] Processing MS
# [329/503] Processing MOS
# [330/503] Processing MSI
# [331/503] Processing MSCI
# [332/503] Processing NDAQ
# [333/503] Processing NTAP
# [334/503] Processing NFLX
# [335/503] Processing NEM
# [336/503] Processing NWSA
# [337/503] Processing NWS
# [338/503] Processing NEE
# [339/503] Processing NKE
# [340/503] Processing NI
# [341/503] Processing NDSN
# [342/503] Processing NSC
# [343/503] Processing NTRS
# [344/503] Processing NOC
# [345/503] Processing NCLH
# [346/503] Processing NRG
# [347/503] Processing NUE
# [348/503] Processing NVDA
# [349/503] Processing NVR
# [350/503] Processing NXPI
# [351/503] Processing ORLY
# [352/503] Processing OXY
# [353/503] Processing ODFL
# [354/503] Processing OMC
# [355/503] Processing ON
# [356/503] Processing OKE
# [357/503] Processing ORCL
# [358/503] Processing OTIS
# [359/503] Processing PCAR
# [360/503] Processing PKG
# [361/503] Processing PLTR
# [362/503] Processing PANW
# [363/503] Processing PARA
# [364/503] Processing PH
# [365/503] Processing PAYX
# [366/503] Processing PAYC
# [367/503] Processing PYPL
# [368/503] Processing PNR
# [369/503] Processing PEP
# [370/503] Processing PFE
# [371/503] Processing PCG
# [372/503] Processing PM
# [373/503] Processing PSX
# [374/503] Processing PNW
# [375/503] Processing PNC
# [376/503] Processing POOL
# [377/503] Processing PPG
# [378/503] Processing PPL
# [379/503] Processing PFG
# [380/503] Processing PG
# [381/503] Processing PGR
# [382/503] Processing PLD
# [383/503] Processing PRU
# [384/503] Processing PEG
# [385/503] Processing PTC
# [386/503] Processing PSA
# [387/503] Processing PHM
# [388/503] Processing PWR
# [389/503] Processing QCOM
# [390/503] Processing DGX
# [391/503] Processing RL
# [392/503] Processing RJF
# [393/503] Processing RTX
# [394/503] Processing O
# [395/503] Processing REG
# [396/503] Processing REGN
# [397/503] Processing RF
# [398/503] Processing RSG
# [399/503] Processing RMD
# [400/503] Processing RVTY
# [401/503] Processing ROK
# [402/503] Processing ROL
# [403/503] Processing ROP
# [404/503] Processing ROST
# [405/503] Processing RCL
# [406/503] Processing SPGI
# [407/503] Processing CRM
# [408/503] Processing SBAC
# [409/503] Processing SLB
# [410/503] Processing STX
# [411/503] Processing SRE
# [412/503] Processing NOW
# [413/503] Processing SHW
# [414/503] Processing SPG
# [415/503] Processing SWKS
# [416/503] Processing SJM
# [417/503] Processing SW
# [418/503] Processing SNA
# [419/503] Processing SOLV
# [420/503] Processing SO
# [421/503] Processing LUV
# [422/503] Processing SWK
# [423/503] Processing SBUX
# [424/503] Processing STT
# [425/503] Processing STLD
# [426/503] Processing STE
# [427/503] Processing SYK
# [428/503] Processing SMCI
# [429/503] Processing SYF
# [430/503] Processing SNPS
# [431/503] Processing SYY
# [432/503] Processing TMUS
# [433/503] Processing TROW
# [434/503] Processing TTWO
# [435/503] Processing TPR
# [436/503] Processing TRGP
# [437/503] Processing TGT
# [438/503] Processing TEL
# [439/503] Processing TDY
# [440/503] Processing TER
# [441/503] Processing TSLA
# [442/503] Processing TXN
# [443/503] Processing TPL
# [444/503] Processing TXT
# [445/503] Processing TMO
# [446/503] Processing TJX
# [447/503] Processing TKO
# [448/503] Processing TSCO
# [449/503] Processing TT
# [450/503] Processing TDG
# [451/503] Processing TRV
# [452/503] Processing TRMB
# [453/503] Processing TFC
# [454/503] Processing TYL
# [455/503] Processing TSN
# [456/503] Processing USB
# [457/503] Processing UBER
# [458/503] Processing UDR
# [459/503] Processing ULTA
# [460/503] Processing UNP
# [461/503] Processing UAL
# [462/503] Processing UPS
# [463/503] Processing URI
# [464/503] Processing UNH
# [465/503] Processing UHS
# [466/503] Processing VLO
# [467/503] Processing VTR
# [468/503] Processing VLTO
# [469/503] Processing VRSN
# [470/503] Processing VRSK
# [471/503] Processing VZ
# [472/503] Processing VRTX
# [473/503] Processing VTRS
# [474/503] Processing VICI
# [475/503] Processing V
# [476/503] Processing VST
# [477/503] Processing VMC
# [478/503] Processing WRB
# [479/503] Processing GWW
# [480/503] Processing WAB
# [481/503] Processing WBA
# [482/503] Processing WMT
# [483/503] Processing DIS
# [484/503] Processing WBD
# [485/503] Processing WM
# [486/503] Processing WAT
# [487/503] Processing WEC
# [488/503] Processing WFC
# [489/503] Processing WELL
# [490/503] Processing WST
# [491/503] Processing WDC
# [492/503] Processing WY
# [493/503] Processing WSM
# [494/503] Processing WMB
# [495/503] Processing WTW
# [496/503] Processing WDAY
# [497/503] Processing WYNN
# [498/503] Processing XEL
# [499/503] Processing XYL
# [500/503] Processing YUM
# [501/503] Processing ZBRA
# [502/503] Processing ZBH
# [503/503] Processing ZTS
# ✅ All done.

# %%
from google.colab import files
files.download('sp500_fundamentals_colab.csv')
files.download('skipped_tickers_colab.csv')
